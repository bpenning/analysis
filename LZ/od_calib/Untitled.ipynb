# %%
import ROOT as r
h = ROOT.TH1F("gauss","Example histogram",100,-4,4)
h.FillRandom("gaus")
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)
h.Draw()
c.Draw()
# Out:
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: gauss (Potential memory leak).
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: myCanvasName

# %%
files=['filelists/AmLi_1336.root', 'filelists/AmLi_700.root', 'filelists/AmLi_oneZ.root']
for f in files: print(f)
# Out:
# filelists/AmLi_1336.root
# filelists/AmLi_700.root
# filelists/AmLi_oneZ.root

# %%
f=ROOT.TFile('filelists/AmLi_1336.root')
h=f.Get('h1_odLG_nPulses')
h.Print()
c1 = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)
h.Draw()
c1.Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: myCanvasName
# TH1.Print Name  = h1_odLG_nPulses, Entries= 10, Total sum= 2
